# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %%
if not os.path.exists('./model'):
    os.makedirs('./model')
model.save('./model/face-rec.h5')

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# 04318
# Euclidean distance from kanye is 0.8090636
# Euclidean distance from Kunal is 1.1209432
# Euclidean distance from Sumantra is 0.63468564
# Euclidean distance from Vedant is 0.90523124
# Euclidean distance from kanye is 0.73200935
# Euclidean distance from Kunal is 1.0558325
# Euclidean distance from Sumantra is 0.6091586
# Euclidean distance from Vedant is 0.84333974
# Euclidean distance from kanye is 0.7172716
# Euclidean distance from Kunal is 1.0517932
# Euclidean distance from Sumantra is 0.6381373
# Euclidean distance from Vedant is 0.7943159
# Euclidean distance from kanye is 0.6941464
# Euclidean distance from Kunal is 1.1486636
# Euclidean distance from Sumantra is 0.60268027
# Euclidean distance from Vedant is 0.85973155
# Euclidean distance from kanye is 0.69764113
# Euclidean distance from Kunal is 1.019767
# Euclidean distance from Sumantra is 0.61829907
# Euclidean distance from Vedant is 0.7557857
# Euclidean distance from kanye is 0.7721495
# Euclidean distance from Kunal is 1.127293
# Euclidean distance from Sumantra is 0.68542993
# Euclidean distance from Vedant is 0.83054364
# Euclidean distance from kanye is 0.78180647
# Euclidean distance from Kunal is 1.0548671
# Euclidean distance from Sumantra is 0.6483149
# Euclidean distance from Vedant is 0.79657954
# Euclidean distance from kanye is 0.79570574
# Euclidean distance from Kunal is 1.1602312
# Euclidean distance from Sumantra is 0.7701776
# Euclidean distance from Vedant is 0.93216044
# Euclidean distance from kanye is 0.7811268
# Euclidean distance from Kunal is 1.1525667
# Euclidean distance from Sumantra is 0.66795874
# Euclidean distance from Vedant is 0.8876141
# Euclidean distance from kanye is 0.69802064
# Euclidean distance from Kunal is 1.1362742
# Euclidean distance from Sumantra is 0.60823774
# Euclidean distance from Vedant is 0.8258857
# Euclidean distance from kanye is 0.75437945
# Euclidean distance from Kunal is 1.0772585
# Euclidean distance from Sumantra is 0.7043969
# Euclidean distance from Vedant is 0.8461768
# Euclidean distance from kanye is 0.8272788
# Euclidean distance from Kunal is 1.2362143
# Euclidean distance from Sumantra is 0.74424464
# Euclidean distance from Vedant is 0.9401114
# Euclidean distance from kanye is 0.7390271
# Euclidean distance from Kunal is 1.1602914
# Euclidean distance from Sumantra is 0.74213177
# Euclidean distance from Vedant is 0.8774868
# Euclidean distance from kanye is 0.8091968
# Euclidean distance from Kunal is 1.2082212
# Euclidean distance from Sumantra is 0.7016639
# Euclidean distance from Vedant is 0.9298616
# Euclidean distance from kanye is 0.82188267
# Euclidean distance from Kunal is 1.246298
# Euclidean distance from Sumantra is 0.7325517
# Euclidean distance from Vedant is 0.94416076
# Euclidean distance from kanye is 0.81086934
# Euclidean distance from Kunal is 1.18279
# Euclidean distance from Sumantra is 0.6736369
# Euclidean distance from Vedant is 0.9014507
# Euclidean distance from kanye is 0.84960294
# Euclidean distance from Kunal is 1.1848524
# Euclidean distance from Sumantra is 0.7238304
# Euclidean distance from Vedant is 0.9115639
# Euclidean distance from kanye is 0.81215024
# Euclidean distance from Kunal is 1.1328037
# Euclidean distance from Sumantra is 0.65074205
# Euclidean distance from Vedant is 0.83810854
# Euclidean distance from kanye is 0.8586772
# Euclidean distance from Kunal is 1.2661433
# Euclidean distance from Sumantra is 0.7561383
# Euclidean distance from Vedant is 0.95815647
# Euclidean distance from kanye is 0.8317839
# Euclidean distance from Kunal is 1.2394491
# Euclidean distance from Sumantra is 0.74146837
# Euclidean distance from Vedant is 0.91238105
# Euclidean distance from kanye is 0.88688284
# Euclidean distance from Kunal is 1.3054446
# Euclidean distance from Sumantra is 0.84756786
# Euclidean distance from Vedant is 1.0392187
# Euclidean distance from kanye is 0.82897305
# Euclidean distance from Kunal is 1.2597302
# Euclidean distance from Sumantra is 0.7983109
# Euclidean distance from Vedant is 0.93635935
# Euclidean distance from kanye is 0.8618575
# Euclidean distance from Kunal is 1.2851746
# Euclidean distance from Sumantra is 0.800689
# Euclidean distance from Vedant is 1.0002787
# Euclidean distance from kanye is 0.8462684
# Euclidean distance from Kunal is 1.2764469
# Euclidean distance from Sumantra is 0.77282727
# Euclidean distance from Vedant is 1.0205914
# Euclidean distance from kanye is 0.89334583
# Euclidean distance from Kunal is 1.2879311
# Euclidean distance from Sumantra is 0.8260794
# Euclidean distance from Vedant is 1.0269784
# Euclidean distance from kanye is 0.909222
# Euclidean distance from Kunal is 1.3296162
# Euclidean distance from Sumantra is 0.9005005
# Euclidean distance from Vedant is 1.0655234
# Euclidean distance from kanye is 0.93930346
# Euclidean distance from Kunal is 1.3395275
# Euclidean distance from Sumantra is 0.8554215
# Euclidean distance from Vedant is 1.0548204
# Euclidean distance from kanye is 0.93115693
# Euclidean distance from Kunal is 1.2433059
# Euclidean distance from Sumantra is 0.8434726
# Euclidean distance from Vedant is 0.982903
# Euclidean distance from kanye is 0.8042431
# Euclidean distance from Kunal is 1.1737828
# Euclidean distance from Sumantra is 0.68194664
# Euclidean distance from Vedant is 0.8349365
# Euclidean distance from kanye is 0.90899134
# Euclidean distance from Kunal is 1.1361395
# Euclidean distance from Sumantra is 0.77757704
# Euclidean distance from Vedant is 0.91217023
# Euclidean distance from kanye is 0.9060113
# Euclidean distance from Kunal is 1.2319982
# Euclidean distance from Sumantra is 0.8331329
# Euclidean distance from Vedant is 0.9705186
# Euclidean distance from kanye is 0.84625447
# Euclidean distance from Kunal is 1.1222367
# Euclidean distance from Sumantra is 0.7273129
# Euclidean distance from Vedant is 0.8614385
# Euclidean distance from kanye is 0.8148076
# Euclidean distance from Kunal is 1.2034498
# Euclidean distance from Sumantra is 0.7904499
# Euclidean distance from Vedant is 0.91268325
# Euclidean distance from kanye is 0.8736287
# Euclidean distance from Kunal is 1.1409135
# Euclidean distance from Sumantra is 0.82005155
# Euclidean distance from Vedant is 0.82685035
# Euclidean distance from kanye is 0.89221245
# Euclidean distance from Kunal is 1.2539365
# Euclidean distance from Sumantra is 0.7455762
# Euclidean distance from Vedant is 0.9895952
# Euclidean distance from kanye is 0.9443712
# Euclidean distance from Kunal is 1.322853
# Euclidean distance from Sumantra is 0.8629437
# Euclidean distance from Vedant is 1.1314071
# Euclidean distance from kanye is 0.99109405
# Euclidean distance from Kunal is 1.342027
# Euclidean distance from Sumantra is 0.94329953
# Euclidean distance from Vedant is 1.1598549
# Euclidean distance from kanye is 0.91006565
# Euclidean distance from Kunal is 1.3510293
# Euclidean distance from Sumantra is 0.8303919
# Euclidean distance from Vedant is 1.1776112
# Euclidean distance from kanye is 0.9257496
# Euclidean distance from Kunal is 1.3549868
# Euclidean distance from Sumantra is 0.8801574
# Euclidean distance from Vedant is 1.1374943
# Euclidean distance from kanye is 0.96949226
# Euclidean distance from Kunal is 1.3622999
# Euclidean distance from Sumantra is 0.911789
# Euclidean distance from Vedant is 1.1685146
# Euclidean distance from kanye is 0.9543744
# Euclidean distance from Kunal is 1.359101
# Euclidean distance from Sumantra is 0.9446506
# Euclidean distance from Vedant is 1.1703682
# Euclidean distance from kanye is 0.9552464
# Euclidean distance from Kunal is 1.2869307
# Euclidean distance from Sumantra is 0.9377024
# Euclidean distance from Vedant is 1.108081
# Euclidean distance from kanye is 0.8739509
# Euclidean distance from Kunal is 0.93934304
# Euclidean distance from Sumantra is 0.80584264
# Euclidean distance from Vedant is 0.7955927
# Euclidean distance from kanye is 0.95961034
# Euclidean distance from Kunal is 1.0420777
# Euclidean distance from Sumantra is 0.867551
# Euclidean distance from Vedant is 0.9670072
# Euclidean distance from kanye is 0.92789054
# Euclidean distance from Kunal is 1.0355076
# Euclidean distance from Sumantra is 0.8295098
# Euclidean distance from Vedant is 0.9336998
# Euclidean distance from kanye is 0.8602501
# Euclidean distance from Kunal is 0.9562072
# Euclidean distance from Sumantra is 0.79576814
# Euclidean distance from Vedant is 0.83012724
# Euclidean distance from kanye is 0.8277892
# Euclidean distance from Kunal is 1.159715
# Euclidean distance from Sumantra is 0.78442043
# Euclidean distance from Vedant is 0.92583567
# Euclidean distance from kanye is 0.8725791
# Euclidean distance from Kunal is 1.0096837
# Euclidean distance from Sumantra is 0.71927696
# Euclidean distance from Vedant is 0.8426562
# Euclidean distance from kanye is 0.7184977
# Euclidean distance from Kunal is 0.96153826
# Euclidean distance from Sumantra is 0.5989456
# Euclidean distance from Vedant is 0.7683217
# Euclidean distance from kanye is 0.77481043
# Euclidean distance from Kunal is 0.920573
# Euclidean distance from Sumantra is 0.61914366
# Euclidean distance from Vedant is 0.8224235
# Euclidean distance from kanye is 0.78524315
# Euclidean distance from Kunal is 0.90022045
# Euclidean distance from Sumantra is 0.637738
# Euclidean distance from Vedant is 0.74839765
# Euclidean distance from kanye is 0.75264245
# Euclidean distance from Kunal is 1.0942632
# Euclidean distance from Sumantra is 0.5591269
# Euclidean distance from Vedant is 0.8333152
# Euclidean distance from kanye is 0.7469203
# Euclidean distance from Kunal is 1.0099797
# Euclidean distance from Sumantra is 0.54532564
# Euclidean distance from Vedant is 0.78858405
# Euclidean distance from kanye is 0.73580146
# Euclidean distance from Kunal is 0.9420781
# Euclidean distance from Sumantra is 0.5194609
# Euclidean distance from Vedant is 0.73069865
# Euclidean distance from kanye is 0.75509226
# Euclidean distance from Kunal is 1.0820112
# Euclidean distance from Sumantra is 0.57355183
# Euclidean distance from Vedant is 0.8206086
# Euclidean distance from kanye is 0.70354795
# Euclidean distance from Kunal is 1.0099638
# Euclidean distance from Sumantra is 0.54179186
# Euclidean distance from Vedant is 0.77741504
# Euclidean distance from kanye is 0.76809317
# Euclidean distance from Kunal is 1.0270879
# Euclidean distance from Sumantra is 0.5664829
# Euclidean distance from Vedant is 0.816832
# Euclidean distance from kanye is 0.7363716
# Euclidean distance from Kunal is 1.0579934
# Euclidean distance from Sumantra is 0.57136256
# Euclidean distance from Vedant is 0.8402302
# Euclidean distance from kanye is 0.7341893
# Euclidean distance from Kunal is 1.0778464
# Euclidean distance from Sumantra is 0.51810664
# Euclidean distance from Vedant is 0.8821431
# Euclidean distance from kanye is 0.7172546
# Euclidean distance from Kunal is 1.0343419
# Euclidean distance from Sumantra is 0.5456551
# Euclidean distance from Vedant is 0.8452386
# Euclidean distance from kanye is 0.7151075
# Euclidean distance from Kunal is 0.9644238
# Euclidean distance from Sumantra is 0.49376017
# Euclidean distance from Vedant is 0.7227375
# Euclidean distance from kanye is 0.7699411
# Euclidean distance from Kunal is 1.1261302
# Euclidean distance from Sumantra is 0.50868845
# Euclidean distance from Vedant is 0.85461694
# Euclidean distance from kanye is 0.7015903
# Euclidean distance from Kunal is 1.0746555
# Euclidean distance from Sumantra is 0.4925371
# Euclidean distance from Vedant is 0.8095505
# Euclidean distance from kanye is 0.7489583
# Euclidean distance from Kunal is 1.0895445
# Euclidean distance from Sumantra is 0.5942235
# Euclidean distance from Vedant is 0.83676803
# Euclidean distance from kanye is 0.7220464
# Euclidean distance from Kunal is 1.0523368
# Euclidean distance from Sumantra is 0.4956812
# Euclidean distance from Vedant is 0.79029155
# Euclidean distance from kanye is 0.710791
# Euclidean distance from Kunal is 1.0429562
# Euclidean distance from Sumantra is 0.48083165
# Euclidean distance from Vedant is 0.78004783
# Euclidean distance from kanye is 0.75876945
# Euclidean distance from Kunal is 1.1401939
# Euclidean distance from Sumantra is 0.5811071
# Euclidean distance from Vedant is 0.9212495
# Euclidean distance from kanye is 0.7139931
# Euclidean distance from Kunal is 1.0032853
# Euclidean distance from Sumantra is 0.49565718
# Euclidean distance from Vedant is 0.7619367
# Euclidean distance from kanye is 0.7185113
# Euclidean distance from Kunal is 1.0184361
# Euclidean distance from Sumantra is 0.57281077
# Euclidean distance from Vedant is 0.80568504
# Euclidean distance from kanye is 0.7858172
# Euclidean distance from Kunal is 1.0792797
# Euclidean distance from Sumantra is 0.5470776
# Euclidean distance from Vedant is 0.8385579
# Euclidean distance from kanye is 0.7655826
# Euclidean distance from Kunal is 1.0917655
# Euclidean distance from Sumantra is 0.5800043
# Euclidean distance from Vedant is 0.9263691
# Euclidean distance from kanye is 0.7560201
# Euclidean distance from Kunal is 1.0837399
# Euclidean distance from Sumantra is 0.57473516
# Euclidean distance from Vedant is 0.87822133
# Euclidean distance from kanye is 0.8760554
# Euclidean distance from Kunal is 1.0056058
# Euclidean distance from Sumantra is 0.7174683
# Euclidean distance from Vedant is 0.8917128
# Euclidean distance from kanye is 0.7977105
# Euclidean distance from Kunal is 1.2068293
# Euclidean distance from Sumantra is 0.6630079
# Euclidean distance from Vedant is 0.912279
# Euclidean distance from kanye is 0.8392948
# Euclidean distance from Kunal is 1.2463886
# Euclidean distance from Sumantra is 0.78580076
# Euclidean distance from Vedant is 0.9484
# Euclidean distance from kanye is 0.84423155
# Euclidean distance from Kunal is 1.2951397
# Euclidean distance from Sumantra is 0.6992424
# Euclidean distance from Vedant is 1.0157403
# Euclidean distance from kanye is 0.8912611
# Euclidean distance from Kunal is 1.2030848
# Euclidean distance from Sumantra is 0.6957049
# Euclidean distance from Vedant is 0.94057256
# Euclidean distance from kanye is 0.8583419
# Euclidean distance from Kunal is 1.2618624
# Euclidean distance from Sumantra is 0.7110375
# Euclidean distance from Vedant is 0.952895
# Euclidean distance from kanye is 0.86168885
# Euclidean distance from Kunal is 1.2304643
# Euclidean distance from Sumantra is 0.7251555
# Euclidean distance from Vedant is 0.95821756
# Euclidean distance from kanye is 0.9315039
# Euclidean distance from Kunal is 1.3050815
# Euclidean distance from Sumantra is 0.79237103
# Euclidean distance from Vedant is 1.0184234
# Euclidean distance from kanye is 0.8698429
# Euclidean distance from Kunal is 1.1977414
# Euclidean distance from Sumantra is 0.7154903
# Euclidean distance from Vedant is 0.90720224
# Euclidean distance from kanye is 0.89339936
# Euclidean distance from Kunal is 1.2564104
# Euclidean distance from Sumantra is 0.77159876
# Euclidean distance from Vedant is 0.99084526
# Euclidean distance from kanye is 0.93683875
# Euclidean distance from Kunal is 1.256938
# Euclidean distance from Sumantra is 0.81515276
# Euclidean distance from Vedant is 0.9897021
# Euclidean distance from kanye is 0.8930575
# Euclidean distance from Kunal is 1.2318505
# Euclidean distance from Sumantra is 0.7652771
# Euclidean distance from Vedant is 0.97492695
# Euclidean distance from kanye is 0.937509
# Euclidean distance from Kunal is 1.2332113
# Euclidean distance from Sumantra is 0.7819956
# Euclidean distance from Vedant is 0.96454895
# Euclidean distance from kanye is 0.91491205
# Euclidean distance from Kunal is 1.2701163
# Euclidean distance from Sumantra is 0.83238286
# Euclidean distance from Vedant is 1.0001122
# Euclidean distance from kanye is 0.9063115
# Euclidean distance from Kunal is 1.2722883
# Euclidean distance from Sumantra is 0.80315095
# Euclidean distance from Vedant is 0.9818924
# Euclidean distance from kanye is 0.9269455
# Euclidean distance from Kunal is 1.2715597
# Euclidean distance from Sumantra is 0.85487735
# Euclidean distance from Vedant is 1.030064
# Euclidean distance from kanye is 0.8516229
# Euclidean distance from Kunal is 1.1818081
# Euclidean distance from Sumantra is 0.7546555
# Euclidean distance from Vedant is 0.9647136
# Euclidean distance from kanye is 0.80250645
# Euclidean distance from Kunal is 1.2169847
# Euclidean distance from Sumantra is 0.711005
# Euclidean distance from Vedant is 0.9089156
# Euclidean distance from kanye is 0.8693284
# Euclidean distance from Kunal is 1.2185134
# Euclidean distance from Sumantra is 0.7686458
# Euclidean distance from Vedant is 0.9775318
# Euclidean distance from kanye is 0.88523716
# Euclidean distance from Kunal is 1.2602254
# Euclidean distance from Sumantra is 0.80086845
# Euclidean distance from Vedant is 0.9706073
# Euclidean distance from kanye is 0.8528456
# Euclidean distance from Kunal is 1.2615902
# Euclidean distance from Sumantra is 0.76235026
# Euclidean distance from Vedant is 0.9693221
# Euclidean distance from kanye is 0.871485
# Euclidean distance from Kunal is 1.2198466
# Euclidean distance from Sumantra is 0.7577318
# Euclidean distance from Vedant is 0.9725926
# Euclidean distance from kanye is 0.9028584
# Euclidean distance from Kunal is 1.2296466
# Euclidean distance from Sumantra is 0.77843577
# Euclidean distance from Vedant is 0.95976317
# Euclidean distance from kanye is 0.90371525
# Euclidean distance from Kunal is 1.2230009
# Euclidean distance from Sumantra is 0.7567032
# Euclidean distance from Vedant is 1.0083923
# Euclidean distance from kanye is 0.9191087
# Euclidean distance from Kunal is 1.2633908
# Euclidean distance from Sumantra is 0.8763835
# Euclidean distance from Vedant is 1.0296237
# Euclidean distance from kanye is 0.8758439
# Euclidean distance from Kunal is 1.2560492
# Euclidean distance from Sumantra is 0.81990105
# Euclidean distance from Vedant is 1.0213183
# Euclidean distance from kanye is 0.88534695
# Euclidean distance from Kunal is 1.2799937
# Euclidean distance from Sumantra is 0.84339046
# Euclidean distance from Vedant is 1.0236784
# Euclidean distance from kanye is 0.8401408
# Euclidean distance from Kunal is 1.2173282
# Euclidean distance from Sumantra is 0.79593635
# Euclidean distance from Vedant is 0.97827595
# Euclidean distance from kanye is 0.8965663
# Euclidean distance from Kunal is 1.1404893
# Euclidean distance from Sumantra is 0.75512034
# Euclidean distance from Vedant is 0.9406902
# Euclidean distance from kanye is 0.84378207
# Euclidean distance from Kunal is 1.1360098
# Euclidean distance from Sumantra is 0.58863574
# Euclidean distance from Vedant is 0.9089518
# Euclidean distance from kanye is 0.8172525
# Euclidean distance from Kunal is 0.9871521
# Euclidean distance from Sumantra is 0.55882096
# Euclidean distance from Vedant is 0.8569414
# Euclidean distance from kanye is 0.7295743
# Euclidean distance from Kunal is 1.0274928
# Euclidean distance from Sumantra is 0.47590765
# Euclidean distance from Vedant is 0.74937034
# Euclidean distance from kanye is 0.86232764
# Euclidean distance from Kunal is 1.2198222
# Euclidean distance from Sumantra is 0.7016812
# Euclidean distance from Vedant is 1.0227993
# Euclidean distance from kanye is 0.9109378
# Euclidean distance from Kunal is 1.2168992
# Euclidean distance from Sumantra is 0.75651985
# Euclidean distance from Vedant is 1.0359898
# Euclidean distance from kanye is 0.8113555
# Euclidean distance from Kunal is 1.1623447
# Euclidean distance from Sumantra is 0.7208353
# Euclidean distance from Vedant is 0.8988536
# Euclidean distance from kanye is 0.8559915
# Euclidean distance from Kunal is 1.1939962
# Euclidean distance from Sumantra is 0.720941
# Euclidean distance from Vedant is 0.9988936
# Euclidean distance from kanye is 0.8940796
# Euclidean distance from Kunal is 1.1912524
# Euclidean distance from Sumantra is 0.8099293
# Euclidean distance from Vedant is 0.98079795
# Euclidean distance from kanye is 0.87221617
# Euclidean distance from Kunal is 1.2274749
# Euclidean distance from Sumantra is 0.78421247
# Euclidean distance from Vedant is 0.9813503
# Euclidean distance from kanye is 0.9164027
# Euclidean distance from Kunal is 1.3722839
# Euclidean distance from Sumantra is 0.8577552
# Euclidean distance from Vedant is 1.1260766
# Euclidean distance from kanye is 0.91352814
# Euclidean distance from Kunal is 1.3279967
# Euclidean distance from Sumantra is 0.8011847
# Euclidean distance from Vedant is 1.0703673
# Euclidean distance from kanye is 0.84550947
# Euclidean distance from Kunal is 1.2340893
# Euclidean distance from Sumantra is 0.7704798
# Euclidean distance from Vedant is 0.96925676
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c40bafb02c88> in <module>
#       1 input_embeddings = create_input_image_embeddings()
# ----> 2 recognize_faces_in_cam(input_embeddings)
#
# <ipython-input-8-c3397abe576b> in recognize_faces_in_cam(input_embeddings)
#      51                 cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
#      52
# ---> 53         key = cv2.waitKey(100)
#      54         cv2.imshow("Face Recognizer", img)
#      55
#
# KeyboardInterrupt:
